# %%
#import libraries
import torch
import torchvision.transforms as T
from transformers import AutoFeatureExtractor, AutoModel
from PIL import Image
import numpy as np
import pandas as pd
import os

# %%
#setting pretrained model using huggingface Automodel
model_ckpt = "google/vit-base-patch16-224"
extractor = AutoFeatureExtractor.from_pretrained(model_ckpt)
model = AutoModel.from_pretrained(model_ckpt)
#hidden_dim = model.config.hidden_size
# Out:
# /Users/stephenthorpe/anaconda3/envs/pytorch/lib/python3.11/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['vit.pooler.dense.bias', 'vit.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Data transformation chain. Not using this right now as it wouldn't export to tensor properly
transformation_chain = T.Compose(
    [
        # We first resize the input image to 256x256 and then we take center crop.
        T.Resize(int((256 / 224) * extractor.size["height"])),
        T.CenterCrop(extractor.size["height"]),
        T.ToTensor(),
        T.Normalize(mean=extractor.image_mean, std=extractor.image_std),
    ]
)

# %%
# Define the transformation chain for preprocessing images
transformation_chain = extractor.preprocess

# %%
#Function to extract the embedding using the model, hide print if we have a lot of images

def extract(file):
    file = Image.open(file)
    display(file)
    inputs = extractor(images=file, return_tensors="pt")
#    inputs = {k: v.to(model.device) for k, v in inputs.items()}
#    with torch.no_grad():    
    outputs = model(**inputs).last_hidden_state[:, 0]
  #add -> output_hidden_states=True to model() to access hidden layer vectors/tensors  

#  print(len(outputs.pooler_output))
#  print(outputs.pooler_output)
    print('-----------')
    return outputs
    #append .detach().numpy() to remove tensor

# %%
# get embeddings from a new image to compare to our dataset
origin_embedding = extract('input-images/' + 'origin-image.webp')
#origin_embedding = list(origin_embedding)
origin_embedding
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=500x469>
# -----------
# tensor([[ 6.0757e-03,  3.5515e-01,  1.5557e+00, -1.2434e+00, -2.2649e+00,
#           5.8638e-01,  9.5084e-01,  6.8821e-01, -3.6526e-01, -2.4592e-01,
#          -8.0307e-01, -5.6614e-01,  1.9655e+00, -6.5450e-01,  6.1170e-01,
#          -1.3710e-01,  2.1928e-01, -5.6308e-01,  4.8314e-01,  1.2246e+00,
#           4.4360e-01, -9.8598e-01, -1.5138e-01,  4.3367e-02, -1.2993e-01,
#          -3.7560e-01,  1.0669e+00, -1.0845e-01, -1.5744e+00, -5.5899e-01,
#          -3.7631e-01, -2.9974e-01, -1.0782e+00, -7.5400e-01,  1.1769e+00,
#          -8.5646e-01,  9.5902e-01,  1.7638e+00, -4.4712e-02,  3.4104e-01,
#           8.6382e-01,  7.2365e-01, -6.2858e-01, -2.4694e+00,  1.4416e+00,
#           7.7583e-01,  3.2983e-01, -1.4489e+00,  4.8019e-01,  9.3617e-01,
#          -1.0624e+00, -7.3801e-01,  5.2379e-01, -3.7807e-01,  2.2816e-01,
#           2.5788e-01, -3.4063e-01, -8.8404e-02, -1.2859e+00,  7.0665e-01,
#          -1.0930e+00, -1.4430e+00, -8.0105e-01,  9.4381e-01,  5.6864e-01,
#          -7.2433e-01,  4.2019e-01, -2.0820e-01,  3.2921e-01,  1.4408e+00,
#          -7.2252e-01, -7.3430e-01, -1.2245e-01, -9.2948e-01,  2.4777e-01,
#          -1.7706e+00, -2.3520e+00, -3.3793e-01, -4.7953e-01, -5.9406e-01,
#          -3.8138e-01,  1.0118e+00, -2.6144e+00,  1.7004e-01, -9.6651e-02,
#          -8.6538e-01,  8.7556e-01,  5.4842e-01, -5.1038e-01, -3.6109e-01,
#           6.3669e-01, -1.8812e-01, -4.5692e-01, -5.5462e-01,  1.0690e+00,
#          -1.1806e-01,  1.0883e+00, -1.1664e+00, -6.6251e-01, -1.0319e+00,
#          -9.8135e-01,  4.5361e-01, -1.9562e-01, -3.9825e-01, -7.8128e-01,
#           8.2522e-01, -7.5938e-01,  1.1101e+00, -6.1234e-01, -6.8576e-01,
#          -1.4884e+00,  5.7549e-01, -4.8621e-01,  7.0332e-01, -5.2443e-01,
#           2.1494e+00,  2.2107e-01, -5.7943e-02, -7.1021e-02,  8.8775e-01,
#           1.4116e-01, -7.7761e-01, -8.0017e-01,  7.4616e-01,  1.7044e-01,
#           1.3300e+00,  7.5116e-01,  7.5169e-01,  2.5775e-01, -1.2197e+00,
#          -1.2827e+00,  3.4709e-01, -1.2986e-01]], grad_fn=<SelectBackward0>)

# %%
#import our dataset with images
#df = pd.read_csv('scraping/EBAY_vinyl-records_2024-05-10-.csv')
df.head(5)
# Out:
#         ebay_id                                              title  \
# 0  4.049467e+11  Vtg Fleetwood Mac - Rumours Vinyl Record LP & ...
# 1  2.261252e+11  Fleetwood Mac - Rumours - 1977 - Warner Bros B...
# 2  3.951387e+11  Barry White Vinyl Record Lot - Can't Get Enoug...
# 3  1.667386e+11  FLEETWOOD MAC - Rumours - Vinyl L.P Warner Bro...
# 4  2.047300e+11  CREAM ERIC CLAPTON LP VINYL LOT ORIGINAL LAYLA...
#
#                                             location  \
# 0  Located in: Henderson, North Carolina, United ...
# 1     Located in: Keyport, New Jersey, United States
# 2  Located in: Merrimack, New Hampshire, United S...
# 3   Located in: Saint Louis, Missouri, United States
# 4     Located in: Patchogue, New York, United States
#
#                                            condition  \
# 0  Used: An item that has been used previously. S...
# 1  Used: An item that has been used previously. S...
# 2  UsedAn item that has been used previously. See...
# 3  Used: An item that has been used previously. S...
# 4  Used: An item that has been used previously. S...
#
#                                             artist release_year  \
# 0                                    Fleetwood Mac         1977
# 1  Fleetwood Mac, Lindsey Buckingham, Stevie Nicks         1977
# 2                             BEATLES, Barry White          NaN
# 3                                    Fleetwood Mac         1977
# 4       Cream, Eric Clapton, Derek and the Dominos          NaN
#
#                                            image_url        sleeve_grading  \
# 0  https://i.ebayimg.com/images/g/8KoAAOSwEFpmLZ5...                   NaN
# 1  https://i.ebayimg.com/images/g/u0cAAOSwGdJmM89...        Good Plus (G+)
# 2  https://i.ebayimg.com/images/g/rVIAAOSwE1NlptS...                   NaN
# 3  https://i.ebayimg.com/images/g/zK0AAOSwEFpmJj0...        Very Good (VG)
# 4  https://i.ebayimg.com/images/g/KSYAAOSwmb1mEZZ...  Very Good Plus (VG+)
#
#          record_grading                  sold_date   sold  shipping_cost  \
# 0                   NaN                        NaN  19.90           4.87
# 1  Very Good Plus (VG+)                        NaN  13.50           4.85
# 2                   NaN                        NaN  49.99            NaN
# 3        Good Plus (G+)  May 06, 2024 16:11:12 PDT  16.00           5.50
# 4        Excellent (EX)  Apr 11, 2024 17:02:23 PDT  41.00           5.61
#
#                       image_file  \
# 0   8KoAAOSwEFpmLZ53_s-l500.webp
# 1   u0cAAOSwGdJmM89m_s-l500.webp
# 2   rVIAAOSwE1NlptSv_s-l500.webp
# 3   zK0AAOSwEFpmJj0Q_s-l500.webp
# 4  KSYAAOSwmb1mEZZh_s-l1600.webp
#
#                                      image_embedding
# 0  [[1.432895, -1.5375918, 0.9917184, -0.6840542,...
# 1  [[1.3305242, -0.16204205, 1.6323817, -1.457420...
# 2  [[0.28039098, 0.6433893, 0.18588823, -1.859955...
# 3  [[0.7910292, 0.19417451, 1.2784475, -1.6964996...
# 4  [[1.3392135, 1.1973602, -1.6119115, -2.3291473...

# %%
image_files = np.array(df.loc[0:50,'image_file'])
embeddings = [] 
for image in image_files:
    print('extracting image:', image)
    embedding = extract('scraping/files/' + image)
    embedding = embedding.detach().numpy() #convert from tensor object back to a normal 2d array
    row = [image, embedding]
    embeddings.append(row)
#add embedding to df for image
# Create a dictionary from the embeddings list
embeddings_dict = {name: embedding for name, embedding in embeddings}
# Update the 'image_embedding' column
df['image_embedding'] = df['image_file'].map(embeddings_dict)
# Out:
# extracting image: 8KoAAOSwEFpmLZ53_s-l500.webp
# -----------
# extracting image: u0cAAOSwGdJmM89m_s-l500.webp
# -----------
# extracting image: rVIAAOSwE1NlptSv_s-l500.webp
# -----------
# extracting image: zK0AAOSwEFpmJj0Q_s-l500.webp
# -----------
# extracting image: KSYAAOSwmb1mEZZh_s-l1600.webp
# -----------
# extracting image: 5ocAAOSwilxmMV~O_s-l1600.webp
# -----------
# extracting image: czIAAOSwC2xlDQ1-_s-l500.webp
# -----------
# extracting image: xO0AAOSwQA9mGDCo_s-l1600.webp
# -----------
# extracting image: NQ4AAOSwWp5mO35B_s-l500.webp
# -----------
# extracting image: 7XMAAOSwZRtmMMZs_s-l1600.webp
# -----------
# extracting image: 7bgAAOSw209luw2R_s-l1600.webp
# -----------
# extracting image: itgAAOSwq5Fl7gkb_s-l1600.webp
# -----------
# extracting image: xX4AAOSwih9mCNah_s-l1600.webp
# -----------
# extracting image: uOgAAOSwsStmFK-u_s-l1600.webp
# -----------
# extracting image: V1MAAOSwkSZl8biO_s-l500.webp
# -----------
# extracting image: s7oAAOSwu5dmMaEM_s-l500.webp
# -----------
# extracting image: nFkAAOSwHUtmGbOU_s-l1600.webp
# -----------
# extracting image: m9IAAOSwJkVmPNGB_s-l1600.webp
# -----------
# extracting image: ~2wAAOSwKGxmKpuE_s-l1600.webp
# -----------
# extracting image: 8PUAAOSwzNBmAbM3_s-l1600.jpg
# -----------
# extracting image: p-wAAOSw82tmLB9H_s-l500.webp
# -----------
# extracting image: m9AAAOSwztBmEout_s-l1600.webp
# -----------
# extracting image: yx0AAOSwH6lmOTjB_s-l1600.webp
# -----------
# extracting image: Z0IAAOSwKK1mN8UT_s-l1600.webp
# -----------
# extracting image: QG0AAOSwFEVmL89i_s-l500.webp
# -----------
# extracting image: 7pMAAOSwyONmMMZc_s-l300.webp
# -----------
# extracting image: xhwAAOSwmZpmM7Uz_s-l1600.webp
# -----------
# extracting image: 0nQAAOSwOjFmNBIF_s-l1600.webp
# -----------
# extracting image: -JkAAOSwHzlmFGVL_s-l1600.webp
# -----------
# extracting image: jjYAAOSw3aVmLWlJ_s-l500.webp
# -----------
# extracting image: K4sAAOSw3eJmJ3y7_s-l1600.webp
# -----------
# extracting image: uh0AAOSwhOdmIsol_s-l500.webp
# -----------
# extracting image: pjYAAOSwwdRmKXEB_s-l500.webp
# -----------
# extracting image: c8MAAOSwZh9lCNXW_s-l500.webp
# -----------
# extracting image: UxsAAOSwe4FmHGDW_s-l1600.webp
# -----------
# extracting image: pOMAAOSwkAll-~Xw_s-l1600.webp
# -----------
# extracting image: LqoAAOSwbbFmMufb_s-l1600.webp
# -----------
# extracting image: n~8AAOSwFzlmL8Qb_s-l1600.webp
# -----------
# extracting image: se0AAOSwNuVmPAbf_s-l500.webp
# -----------
# extracting image: jtUAAOSwd9dmAdub_s-l500.webp
# -----------
# extracting image: oZEAAOSwhMxmNjMt_s-l1600.webp
# -----------
# extracting image: fU0AAOSwjKhmNjNj_s-l300.webp
# -----------
# extracting image: O~wAAOSw42VmM6pJ_s-l500.webp
# -----------
# extracting image: LkUAAOSwmXZmIS4T_s-l500.webp
# -----------
# extracting image: rdYAAOSwr6RmPRSH_s-l1600.webp
# -----------
# extracting image: kEQAAOSw~8JmLo9m_s-l500.webp
# -----------
# extracting image: 5FcAAOSwi5NmITql_s-l1600.webp
# -----------
# extracting image: sk0AAOSwFPNmL4zD_s-l1600.webp
# -----------
# extracting image: mRMAAOSwG0VmMa9I_s-l1600.webp
# -----------
# extracting image: ZaUAAOSw8Y1mNnjI_s-l1600.webp
# -----------
# extracting image: b1gAAOSwfOpmGzzj_s-l1600.webp
# -----------

# %%
from torch.nn.functional import cosine_similarity

# %%
# run through df embeddings and calc cosine distance from original image then order smallest
# to largest with filename as reference
image_embeddings = np.array(df.iloc[0:50, [12, 13]])
distances = []
for i in range(len(image_embeddings)):
    image_file = df.iloc[i, 12]
    image_embedding = df.iloc[i, 13]  
    image_embedding = torch.tensor(image_embedding) #change back to a tensor object to use below
    dist = cosine_similarity(origin_embedding, image_embedding, dim=1).detach().numpy()
#    dist = float(distance.cdist([origin_embedding], [image_embedding], metric)[0])
    row = [image_file, dist]
    distances.append(row) 
#sorted_distances = sorted(distances, reverse = False)#as we are measure similarity and NOT distance don't reverse list 
sorted_distances = sorted(distances, key=lambda x: x[1])

# %%
sorted_distances
# Out:
# [['7pMAAOSwyONmMMZc_s-l300.webp', array([0.1156846], dtype=float32)],
#  ['7XMAAOSwZRtmMMZs_s-l1600.webp', array([0.1310614], dtype=float32)],
#  ['0nQAAOSwOjFmNBIF_s-l1600.webp', array([0.20029044], dtype=float32)],
#  ['c8MAAOSwZh9lCNXW_s-l500.webp', array([0.20407608], dtype=float32)],
#  ['n~8AAOSwFzlmL8Qb_s-l1600.webp', array([0.22806565], dtype=float32)],
#  ['V1MAAOSwkSZl8biO_s-l500.webp', array([0.23211738], dtype=float32)],
#  ['jtUAAOSwd9dmAdub_s-l500.webp', array([0.25622174], dtype=float32)],
#  ['5ocAAOSwilxmMV~O_s-l1600.webp', array([0.260482], dtype=float32)],
#  ['ZaUAAOSw8Y1mNnjI_s-l1600.webp', array([0.26190034], dtype=float32)],
#  ['yx0AAOSwH6lmOTjB_s-l1600.webp', array([0.27270764], dtype=float32)],
#  ['xO0AAOSwQA9mGDCo_s-l1600.webp', array([0.2764693], dtype=float32)],
#  ['xX4AAOSwih9mCNah_s-l1600.webp', array([0.27837127], dtype=float32)],
#  ['itgAAOSwq5Fl7gkb_s-l1600.webp', array([0.288583], dtype=float32)],
#  ['xhwAAOSwmZpmM7Uz_s-l1600.webp', array([0.29335257], dtype=float32)],
#  ['LkUAAOSwmXZmIS4T_s-l500.webp', array([0.29495135], dtype=float32)],
#  ['rdYAAOSwr6RmPRSH_s-l1600.webp', array([0.3089754], dtype=float32)],
#  ['7bgAAOSw209luw2R_s-l1600.webp', array([0.30960155], dtype=float32)],
#  ['UxsAAOSwe4FmHGDW_s-l1600.webp', array([0.31474897], dtype=float32)],
#  ['m9IAAOSwJkVmPNGB_s-l1600.webp', array([0.32197687], dtype=float32)],
#  ['m9AAAOSwztBmEout_s-l1600.webp', array([0.32926443], dtype=float32)],
#  ['LqoAAOSwbbFmMufb_s-l1600.webp', array([0.344708], dtype=float32)],
#  ['pOMAAOSwkAll-~Xw_s-l1600.webp', array([0.34636682], dtype=float32)],
#  ['zK0AAOSwEFpmJj0Q_s-l500.webp', array([0.3474852], dtype=float32)],
#  ['se0AAOSwNuVmPAbf_s-l500.webp', array([0.35643092], dtype=float32)],
#  ['nFkAAOSwHUtmGbOU_s-l1600.webp', array([0.35934216], dtype=float32)],
#  ['QG0AAOSwFEVmL89i_s-l500.webp', array([0.36198875], dtype=float32)],
#  ['sk0AAOSwFPNmL4zD_s-l1600.webp', array([0.38399988], dtype=float32)],
#  ['kEQAAOSw~8JmLo9m_s-l500.webp', array([0.39386457], dtype=float32)],
#  ['oZEAAOSwhMxmNjMt_s-l1600.webp', array([0.42491245], dtype=float32)],
#  ['uh0AAOSwhOdmIsol_s-l500.webp', array([0.42497128], dtype=float32)],
#  ['5FcAAOSwi5NmITql_s-l1600.webp', array([0.4267236], dtype=float32)],
#  ['Z0IAAOSwKK1mN8UT_s-l1600.webp', array([0.42953318], dtype=float32)],
#  ['K4sAAOSw3eJmJ3y7_s-l1600.webp', array([0.43602458], dtype=float32)],
#  ['czIAAOSwC2xlDQ1-_s-l500.webp', array([0.43928033], dtype=float32)],
#  ['-JkAAOSwHzlmFGVL_s-l1600.webp', array([0.4502829], dtype=float32)],
#  ['rVIAAOSwE1NlptSv_s-l500.webp', array([0.45100042], dtype=float32)],
#  ['KSYAAOSwmb1mEZZh_s-l1600.webp', array([0.45246875], dtype=float32)],
#  ['uOgAAOSwsStmFK-u_s-l1600.webp', array([0.4616712], dtype=float32)],
#  ['jjYAAOSw3aVmLWlJ_s-l500.webp', array([0.4626961], dtype=float32)],
#  ['~2wAAOSwKGxmKpuE_s-l1600.webp', array([0.46438158], dtype=float32)],
#  ['8KoAAOSwEFpmLZ53_s-l500.webp', array([0.4824394], dtype=float32)],
#  ['p-wAAOSw82tmLB9H_s-l500.webp', array([0.5257265], dtype=float32)],
#  ['8PUAAOSwzNBmAbM3_s-l1600.jpg', array([0.57817113], dtype=float32)],
#  ['mRMAAOSwG0VmMa9I_s-l1600.webp', array([0.61602557], dtype=float32)],
#  ['fU0AAOSwjKhmNjNj_s-l300.webp', array([0.6629609], dtype=float32)],
#  ['NQ4AAOSwWp5mO35B_s-l500.webp', array([0.70415384], dtype=float32)],
#  ['pjYAAOSwwdRmKXEB_s-l500.webp', array([0.7092403], dtype=float32)],
#  ['s7oAAOSwu5dmMaEM_s-l500.webp', array([0.71901447], dtype=float32)],
#  ['u0cAAOSwGdJmM89m_s-l500.webp', array([0.79787755], dtype=float32)],
#  ['O~wAAOSw42VmM6pJ_s-l500.webp', array([0.80759346], dtype=float32)]]

# %%
#sorted_distances = sorted(distances, key=lambda x: x[1])

# %%
# display a list of top x most similar images/items with price etc:
print('Your items value based on',len(sorted_distances), 'comparable items sold is:')
print('')
print('--$',df['sold'].mean(),'--')
print('')
print('-> Min Price sold: $',df['sold'].min())
print('-> Max Price sold: $',df['sold'].max())
print(' ')
print('Details -> Top ', len(sorted_distances), ' most similar items found:')
print('')
i = 0
for image, distance in sorted_distances:
    file = Image.open('scraping/files/' + image).convert('L').resize(IMAGE_SHAPE)
    display(file)
    print('Distance from original:', distance)
#would be awesome to get a historic value of item (over past year at 1 month increments?)
#factor in other things like location, condition -> see records VG VG+ etc
# Out:
# Your items value based on 50 comparable items sold is:
#
# --$ 28.49846341463415 --
#
# -> Min Price sold: $ 0.99
# -> Max Price sold: $ 718.0
#
# Details -> Top  50  most similar items found:
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.1156846]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.1310614]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.20029044]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.20407608]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.22806565]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.23211738]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.25622174]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.260482]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.26190034]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.27270764]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.2764693]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.27837127]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.288583]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.29335257]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.29495135]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.3089754]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.30960155]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.31474897]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.32197687]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.32926443]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.344708]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.34636682]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.3474852]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.35643092]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.35934216]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.36198875]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.38399988]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.39386457]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.42491245]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.42497128]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.4267236]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.42953318]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.43602458]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.43928033]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.4502829]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.45100042]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.45246875]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.4616712]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.4626961]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.46438158]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.4824394]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.5257265]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.57817113]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.61602557]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.6629609]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.70415384]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.7092403]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.71901447]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.79787755]
# <PIL.Image.Image image mode=L size=224x224>
# Distance from original: [0.80759346]
